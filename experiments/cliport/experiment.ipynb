# %%
# %load_ext autoreload
# %matplotlib inline

# %%
# python -m pip install 'git+https://github.com/MaureenZOU/detectron2-xyz.git'

import numpy as np

from PIL import Image
import matplotlib.pyplot as plt

import sys
sys.path.append("../../")
import os

from utils.logging import CustomLogger
from utils import logging
from agents import agent_factory

from executor import SimpleExecutor, LineWiseExecutor

from utils.image_utils import visualize_image

# %%
logger = CustomLogger()
logging.set_logger(logger)

# %%
import numpy as np
np.random.seed(114514)

# %%
from environments.ur5_simulation.env import UR5SimulationEnv
env = UR5SimulationEnv()
env.setup("cliport_put-block-in-bowl-seen-colors")
# Out:
# pybullet build time: Nov 28 2023 23:45:17
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# argc=2
# argv[0] = --unused
# argv[1] = --start_demo_name=Physics Server
# ExampleBrowserThreadFunc started
# X11 functions dynamically loaded using dlopen/dlsym OK!
# X11 functions dynamically loaded using dlopen/dlsym OK!
# Creating context
# Created GL 3.3 context
# Direct GLX rendering context obtained
# Making context current
# GL_VENDOR=NVIDIA Corporation
# GL_RENDERER=NVIDIA GeForce GTX 1080/PCIe/SSE2
# GL_VERSION=3.3.0 NVIDIA 470.141.03
# GL_SHADING_LANGUAGE_VERSION=3.30 NVIDIA via Cg compiler
# pthread_getconcurrency()=0
# Version = 3.3.0 NVIDIA 470.141.03
# Vendor = NVIDIA Corporation
# Renderer = NVIDIA GeForce GTX 1080/PCIe/SSE2
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# ven = NVIDIA Corporation
# ven = NVIDIA Corporation
# {'task': <environments.ur5_simulation.simulation.tasks.put_block_in_bowl.PutBlockInBowlSeenColors at 0x7fd9a2a9ca60>}

# %%
def run_experiment(env, agent, prompt, debug=True):
    print("Image before planning: ")
    image = env.get_image()
    visualize_image(image)
    plan_result = agent.try_plan(prompt, image)
    print(plan_result)
    print("Annotated image: ")
    visualize_image(plan_result.annotated_image)
    
    if not plan_result.success:
        return
        
    # executor = LineWiseExecutor(env.get_execution_context(), pause_every_line=True)
    executor = SimpleExecutor(env.get_execution_context())
    # Build a context containing the masks for the plan code to access
    context = {"regions": [mask["segmentation"] for mask in plan_result.masks]}
    executor.execute_plan(plan_result.plan_code, additional_context=context)

    print("After manipulation: ")
    visualize_image(env.get_image())

    return plan_result

# %% [markdown]
# Specify Your task here.

# %%
prompt="""Task: Put the green blocks into the blue plates."""

# %%
agent = agent_factory("DetVLM")
# agent.configs["img_size"] = 640
plan_result = run_experiment(env, agent, prompt)
# Out:
# Image before planning:

# %%
visualize_image(plan_result.annotated_image, mask=plan_result.masks[0]["segmentation"])

# %%
visualize_image(plan_result.annotated_image, points=[(0.2954279015240328, 0.375), (0.283704572098476, 0.6484375)])

# %%
image = env.get_image()
agent = agent_factory("SegVLM")
agent.configs["img_size"] = 640
plan_result = agent.plan(prompt, image)
plan_result
# Out:
# PlanResult(success=True,
#  error_message=None,
#  plan_raw="```python\npick(regions[13]) # Pick up the red block\nplace(regions[34], 'inside') # Place the red block inside the green bowl\n```",
#  masks=[{'segmentation': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'segmentation': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}],
#  prompt='Task: Put the red block into the green bowl.',
#  plan_code="\npick(regions[0]) # Pick up the red block\nplace(regions[1], 'inside') # Place the red block inside the green bowl\n",
#  annotated_image=<PIL.Image.Image image mode=RGB size=853x640 at 0x7FC048623C70>,
#  info_dict={'configs': {'img_size': 640, 'label_mode': '1', 'alpha': 0.05}})

# %%
agent = agent_factory("DetVLM")
agent.configs["img_size"] = 640
plan_result = run_experiment(env, agent, prompt)
# Out:
# Image before planning:
# PlanResult(success=True,
#  error_message=None,
#  plan_raw="```python\npick(regions[7])\nplace(regions[4], 'inside')\n```",
#  masks=[{'segmentation': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'segmentation': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}],
#  prompt='Task: Put the red block into the green bowl.',
#  plan_code="\npick(regions[1])\nplace(regions[0], 'inside')\n",
#  annotated_image=<PIL.Image.Image image mode=RGB size=853x640 at 0x7F6A2F09C760>,
#  info_dict={'configs': {'img_size': 640, 'label_mode': '1', 'alpha': 0.75}})
# Annotated image:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/yuhong/LargePlanner/experiment.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> agent = agent_factory("DetVLM")
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> agent.configs["img_size"] = 640
# ----> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> plan_result = run_experiment(env, agent, prompt)
#
# /home/yuhong/LargePlanner/experiment.ipynb Cell 12 line 1
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> print("Annotated image: ")
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> show_image(plan_result.annotated_image)
# ---> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> executor = Executor(env.get_execution_context(), pause_every_line=True)
#      <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> # Build a context containing the masks for the plan code to access
#      <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> context = {"regions": [mask["segmentation"] for mask in plan_result.masks]}
#
# NameError: name 'Executor' is not defined

# %%
agent = agent_factory("DetLLM")
agent.configs["img_size"] = 640
plan_result = run_experiment(env, agent, prompt)
# Out:
# Image before planning:
# PlanResult(success=True,
#  error_message=None,
#  plan_raw='```python\n# Plan\n# 1. Pick the block \n# 2. Place the block inside the bowl \n\nblock = "block"\nbowl = "green bowl"\n\n# picking up the block\npick(block)\n\n# placing the block inside the bowl\nplace(block, \'inside\')\n```',
#  masks=[],
#  prompt='List of objects detected (coordinates are in (x1,y1), (x2, y2) order):\n- block (coordinates: (0.72, 0.85), (0.81, 0.98))\n\nTask: Put the red block into the green bowl.',
#  plan_code='\n# Plan\n# 1. Pick the block \n# 2. Place the block inside the bowl \n\nblock = "block"\nbowl = "green bowl"\n\n# picking up the block\npick(block)\n\n# placing the block inside the bowl\nplace(block, \'inside\')\n',
#  annotated_image=<PIL.Image.Image image mode=RGB size=853x640 at 0x7FDE540E8550>,
#  info_dict={'configs': {'img_size': 640, 'alpha': 0.7, 'include_coordinates': True}, 'detected_objects': [{'score': 0.5527634024620056, 'bbox': [0.7156502306461334, 0.8495150124712381, 0.8084563910961151, 0.9839177247078623], 'box_name': 'block', 'objectness': 0.33056923747062683}]})
# Annotated image:
# (Executor) Executing line 6: block = "block"
# (Executor) Executing line 7: bowl = "green bowl"
# (Executor) Executing line 10: pick(block)
# (Executor) Executing line 13: place(block, 'inside')
# Error on line 13: '>' not supported between instances of 'str' and 'int'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/yuhong/LargePlanner/experiment.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> agent = agent_factory("DetLLM")
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> agent.configs["img_size"] = 640
# ----> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> plan_result = run_experiment(env, agent, prompt)
#
# /home/yuhong/LargePlanner/experiment.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> # Build a context containing the masks for the plan code to access
#      <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> context = {"regions": [mask["segmentation"] for mask in plan_result.masks]}
# ---> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> executor.execute_plan(plan_result.plan_code, additional_context=context)
#      <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a> print("After manipulation: ")
#      <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> show_image(env.get_image())
#
# File ~/LargePlanner/executor.py:146, in LineWiseExecutor.execute_plan(self, plan_code, additional_context)
#     144         print("Execution timed out.", file=sys.stderr)
#     145 else:
# --> 146     self._execute_with_trace(plan_code, execution_context)
#
# File ~/LargePlanner/executor.py:129, in LineWiseExecutor._execute_with_trace(self, code, env)
#     127 except Exception as e:
#     128     print(f"Error on line {self.last_line}: {str(e)}", file=sys.stderr)
# --> 129     raise e
#     130 finally:
#     131     sys.settrace(None)
#
# File ~/LargePlanner/executor.py:126, in LineWiseExecutor._execute_with_trace(self, code, env)
#     124     self.compiled_code = compile(code, "PlanCode", "exec")
#     125     sys.settrace(self._trace_function)
# --> 126     exec(code, env)
#     127 except Exception as e:
#     128     print(f"Error on line {self.last_line}: {str(e)}", file=sys.stderr)
#
# File <string>:13
#
# File ~/LargePlanner/environments/ur5_simulation/__init__.py:63, in UR5SimulationEnv.get_execution_context.<locals>.place(obj, orientation)
#      61     raise PlanExecutionError("Trying to place an object when the grasper is currently holding nothing.")
#      62 # Translate mask to center point
# ---> 63 pick_point = find_mask_center_point(grasper_holding)
#      64 place_point = find_mask_center_point(obj)
#      65 # Actual call to simulated env
#
# File ~/LargePlanner/environments/ur5_simulation/__init__.py:13, in find_mask_center_point(binary_mask)
#      12 def find_mask_center_point(binary_mask):
# ---> 13     binary_mask = (binary_mask > 0).astype(np.uint8) * 255  # Make cv2 happy
#      14     height, width = binary_mask.shape
#      15     binary_mask = np.pad(binary_mask, ((1, 1), (1, 1)), 'constant')
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
agent = agent_factory("VLMDet")
agent.configs["img_size"] = 640
plan_result = run_experiment(env, agent, prompt)
# Out:
# Image before planning:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/yuhong/LargePlanner/experiment.ipynb Cell 14 line 3
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> agent = agent_factory("VLMDet")
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> agent.configs["img_size"] = 640
# ----> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> plan_result = run_experiment(env, agent, prompt)
#
# /home/yuhong/LargePlanner/experiment.ipynb Cell 14 line 5
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> image = env.get_image()
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> show_image(image)
# ----> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> plan_result = agent.plan(prompt, image)
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> print(plan_result)
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> print("Annotated image: ")
#
# File ~/LargePlanner/agent/agents.py:509, in VLMDet.plan(self, prompt, image)
#     503     processed_image = resize_image(image, self.configs["img_size"])
#     505 # Generate a textual response from VLM
#     506 plan_raw = self.vlm.chat(
#     507     prompt=prompt,
#     508     image=processed_image,
# --> 509     meta_prompt=self.meta_prompt.format(action_space=self.action_space)
#     510 )
#     512 # Extract objects of interest from VLM's response
#     513 plan_code, object_names_and_aliases = self.extract_objects_of_interest_from_vlm_response(plan_raw)
#
# KeyError: '"name"'

# %%
agent = agent_factory("VLMDetInspect")
agent.configs["img_size"] = 640
plan_result = run_experiment(env, agent, prompt)
# Out:
# Image before planning:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /home/yuhong/LargePlanner/experiment.ipynb Cell 15 line 3
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> agent = agent_factory("VLMDetInspect")
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> agent.configs["img_size"] = 640
# ----> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> plan_result = run_experiment(env, agent, prompt)
#
# /home/yuhong/LargePlanner/experiment.ipynb Cell 15 line 5
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> image = env.get_image()
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> show_image(image)
# ----> <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a> plan_result = agent.plan(prompt, image)
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=5'>6</a> print(plan_result)
#       <a href='vscode-notebook-cell:/home/yuhong/LargePlanner/experiment.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a> print("Annotated image: ")
#
# File ~/LargePlanner/agent/agents.py:678, in VLMDetInspect.plan(self, prompt, image)
#     676 # Extract objects of interest from VLM's response
#     677 plan_code, object_names_and_aliases = self.extract_objects_of_interest_from_vlm_response(plan_raw)
# --> 678 if objects_of_interest is None:
#     679     return PlanResult(
#     680         success=False,
#     681         error_message=f"Could not extract objects of intereset.",
#     682         info_dict=dict(configs=self.configs, plan_raw_before_inspect=plan_raw)
#     683     )
#     685 objects_of_interest = [obj["name"] for obj in object_names_and_aliases]
#
# UnboundLocalError: local variable 'objects_of_interest' referenced before assignment

# %%
logger.save_logs_to_html_file("result.html")
